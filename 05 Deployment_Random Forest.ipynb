# %%
import pickle

# %%
load_model = pickle.load(open("finalized_model_randomforest.sav",'rb'))
result=load_model.predict([[100,200,300,400,500]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([34804.5838])

# %%
load_model = pickle.load(open("finalized_model_randomforest.sav",'rb'))
result=load_model.predict([[600,200,300,700,800]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([38603.5684])

# %%
load_model = pickle.load(open("finalized_model_randomforest.sav",'rb'))
result=load_model.predict([[200,200,300,800,900]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([34804.5838])

# %%
load_model = pickle.load(open("finalized_model_randomforest.sav",'rb'))
result=load_model.predict([[200,200,300,800,900]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([36663.478])
