# %%
import pickle

# %%
load_model = pickle.load(open("finalized_model_multiplelinearregression.sav",'rb'))
result=load_model.predict([[100,200,300,400,500]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[380109.682046]])

# %%
load_model = pickle.load(open("finalized_model_multiplelinearregression.sav",'rb'))
result=load_model.predict([[200,300,400,500,600]])
result
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[456977.74373549]])
